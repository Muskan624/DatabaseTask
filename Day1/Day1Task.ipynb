# %%
#Task1
#creating Database inside which creting tables Attribute and Dress
import mysql.connector as conn
import logging as log
log.basicConfig(filename='info.log',level=log.INFO,  format="%(asctime)s %(levelname)s %(name)s  %(message)s " )
try:
    mydb=conn.connect(host='localhost',user='root',passwd='Somu123')
    print(mydb)
    log.info("Connected with Database")
   ##creating cursor variable that behaves like pointer and go one by one to table and perform operations like read,write etc
    cursor=mydb.cursor()
    #crerating Database and Table for the given dataset
    cursor.execute("create database TaskDataset")
    log.info("Database created successfully")

    cursor.execute("create table TaskDataset.Attribute(Dress_ID int(20),Style varchar(15),Price varchar(15),Rating float,Size varchar(15), Season varchar(15), NeckLine varchar(15), SleeveLength varchar(15), waiseline	varchar(15),Material varchar(15), FabricType varchar(15), Decoration varchar(15), PatternType varchar(15), Recommendation int(20))")

    log.info("Attribute Table created")
    cursor.execute("""create table TaskDataset.Dress(Dress_ID int, `29/8/2013` int,
        `31/8/2013` int,`09-02-2013` int,`09-04-2013` int,`09-06-2013` int,
        `09-08-2013` int,`09-10-2013` int,`09-12-2013` int,`14/9/2013` int,`16/9/2013` int,
        `18/9/2013` int,`20/9/2013` int,`22/9/2013` int,`24/9/2013` int,`26/9/2013` int,
        `28/9/2013` int,`30/9/2013` int,`10-02-2013` int,`10-04-2013` int,`10-06-2013` int,
        `10-08-2010` int,`10-10-2013` int,`10-12-2013` int)""")

    print(cursor.fetchall())
    log.info("Dress table created ")
except Exception  as e:
    log.info(e)
    print(e)
# Out:
# ...
# []

# %%
#task
#Bulk upload
import pandas as pd
import json
import pymongo

pf=pd.read_excel(r"C:\Users\Muskan Sinha\Desktop\ineuron\Datasets\data fsds\Attribute DataSet.xlsx")
print(pf)

print("__________________________________________________________")

pl=pd.read_excel(r"C:\Users\Muskan Sinha\Desktop\ineuron\Datasets\data fsds\Dress Sales.xlsx")
print(pl)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration PatternType  \
# 0      sleevless    empire            NaN     chiffon     ruffles      animal
# ...

# %%
print(pf.head())
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration PatternType  Recommendation
# 0    empire            NaN    chiffon     ruffles      animal               1
# 1   natural     microfiber        NaN     ruffles      animal               0
# 2   natural       polyster        NaN         NaN       print               0
# 3   natural           silk    chiffon  embroidary       print               1
# 4   natural  chiffonfabric    chiffon         bow         dot               0

# %%
from sqlalchemy import create_engine
import mysql.connector as conn
import pymongo

engine = create_engine(
             "mysql+pymysql://" + "root" + ":" + "Somu123" + "@" + "localhost" + ":" + "3306" + "/" + "taskdataset" + "?" + "charset=utf8mb4")

conn = engine.connect()
#insert into  table
excel_file = pd.ExcelFile(r"C:\Users\Muskan Sinha\Desktop\ineuron\Datasets\data fsds\Attribute DataSet.xlsx")
excel_dataframe = excel_file.parse(sheet_name="Sheet1")
#excel_dataframe = excel_dataframe.astype(object).where(pd.notnull(excel_dataframe), None)
excel_dataframe.to_sql("attribute", conn, if_exists="append",index=False)

# %%
#insert into dress_sales table
excel_file = pd.ExcelFile(r"C:\Users\Muskan Sinha\Desktop\ineuron\Datasets\data fsds\Dress Sales.xlsx")
excel_dataframe = excel_file.parse(sheet_name="Sheet1")
#excel_dataframe = excel_dataframe.astype(object).where(pd.notnull(excel_dataframe), None)
excel_dataframe.to_sql("dress", conn, if_exists="replace",index=False)

# %%
#reading from sql as dataframe
from sqlalchemy import create_engine
import mysql.connector as conn
import pymongo
import pandas as pd
import certifi
engine = create_engine(
             "mysql+pymysql://" + "root" + ":" + "Somu123" + "@" + "localhost" + ":" + "3306" + "/" + "taskdataset" + "?" + "charset=utf8mb4")

conn = engine.connect()
df = pd.read_sql("select * from taskdataset.attribute", conn, index_col=None)
df = pd.DataFrame(df, columns = ['Dress_ID', 'Style', 'Price','Rating','Size','Season','Neckline',
                                        'Sleevelength','Waiseline','Material','Fabrictype','Decoration',
                                        'PatternType','Recommendation'])
df.to_json('attribute.json', orient='records', lines=True)
#attribute = pd.read_sql("select * from taskdataset.attribute", conn, index_col='Dress_ID')
#print(attribute)

# %%
ds = pd.read_sql("select * from taskdataset.dress", conn, index_col=None)
ds = pd.DataFrame(df, columns = ['Dress_ID,29/8/2013,31/8/2013,2/9/2013,4/9/2013,6/9/2013,8/9/2013,10/9/2013,12/9/2013,14/9/2013,16/9/2013,18/9/2013,20/9/2013,22/9/2013,24/9/2013,26/9/2013,28/9/2013,30/9/2013,2/10/2013,4/10/2013,6/10/2013,8/10/2010,10/10/2013,12/10/2013'])
ds.to_json('dress.json', orient='records', lines=True)

# %%
#Store this dataset into mongodb
import certifi
client = pymongo.MongoClient("mongodb+srv://Muskan:Somu123@clustermongodb.kmygs.mongodb.net/?retryWrites=true&w=majority",tlsCAFile=certifi.where())
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['clustermongodb-shard-00-01.kmygs.mongodb.net:27017', 'clustermongodb-shard-00-00.kmygs.mongodb.net:27017', 'clustermongodb-shard-00-02.kmygs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-64tn4v-shard-0', tls=True, tlscafile='C:\\Users\\Muskan Sinha\\anaconda3\\lib\\site-packages\\certifi\\cacert.pem'), 'test')

# %%
database = client['TaskData']
collection_a = database['attribute']
collection_d = database['dress_sales']
'''with open('attribute.json') as file:
    file_data1 = json.load(file)
    collection_a.insert_many(file_data1)
with open('dress.json') as file:
    file_data2 = json.load(file)
    collection_d.insert_many(file_data2)'''
file_1 = [json.loads(line) for line in open('attribute.json', 'r')]
collection_a.insert_many(file_1)

file_2 = [json.loads(line) for line in open('dress.json', 'r')]
collection_d.insert_many(file_2)

# %%
#in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
import mysql.connector as conn
mydb=conn.connect(host='localhost',user='root',passwd='Somu123')
print(mydb)
cursor=mydb.cursor()

# %%
engine = create_engine(
             "mysql+pymysql://" + "root" + ":" + "Somu123" + "@" + "localhost" + ":" + "3306" + "/" + "taskdataset" + "?" + "charset=utf8mb4")

conn = engine.connect()
query = '''
select distinct attribute.* , dress.* 
from attribute
left join dress 
on attribute.Dress_ID = dress.Dress_ID
'''
df = pd.read_sql(query , conn)
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material  ... 24/9/2013 26/9/2013 28/9/2013  30/9/2013  \
# 0    empire           None  ...      3554    3624.0      3706     3746.0
# 1   natural     microfiber  ...      2710    2942.0      3258     3354.0
# 2   natural       polyster  ...        11      11.0        11       11.0
# 3   natural           silk  ...      1878    1892.0      1914     1924.0
# 4   natural  chiffonfabric  ...      2032    2156.0      2252     2312.0
#
#    2013-02-10 00:00:00  2013-04-10 00:00:00  2013-06-10 00:00:00  \
# ...

# %%
#Write a sql query to find out how many unique dress that we have based on dress id 
query="select count(distinct(Dress_ID)) from taskdataset.attribute"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(475,)]

# %%
#Try to find out how mnay dress is having recommendation 0
query="select count(*)from taskdataset.attribute where recommendation=0"
cursor.execute(query)
cursor.fetchall()
# Out:
# [(290,)]

# %%
engine = create_engine(
             "mysql+pymysql://" + "root" + ":" + "Somu123" + "@" + "localhost" + ":" + "3306" + "/" + "taskdataset" + "?" + "charset=utf8mb4")

conn = engine.connect()

df = pd.read_sql("select * from taskdataset.dress", conn, index_col=None)
df = df.astype(object).where(pd.notnull(df), None)
dress_sl = pd.DataFrame(df,
                        columns=['Dress_ID', '29.8.2013', '31.8.2013', '2.9.2013', '4.9.2013',
                                 '6.9.2013', '8.9.2013', '10.9.2013', '12.9.2013', '14.9.2013',
                                 '16.9.2013', '18.9.2013', '20.9.2013', '22.9.2013', '24.9.2013',
                                 '26.9.2013', '28.9.2013', '30.9.2013', '2.10.2013', '4.10.2013',
                                 '6.10.2013', '8.10.2013', '10.10.2013', '12.10.2013'])
dress_sl.fillna(0)
dress_sl['total'] = dress_sl[['29.8.2013', '31.8.2013', '2.9.2013', '4.9.2013',
                              '6.9.2013', '8.9.2013',  '10.9.2013', '12.9.2013', '14.9.2013',
                              '16.9.2013', '18.9.2013', '20.9.2013', '22.9.2013', '24.9.2013',
                              '26.9.2013', '28.9.2013', '30.9.2013', '2.10.2013', '4.10.2013',
                              '6.10.2013', '8.10.2013', '10.10.2013', '12.10.2013']].agg('sum', axis=1)
